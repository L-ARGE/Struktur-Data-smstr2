# %%
class Cookie:
    def __init__ (self, color):
        self.color = color

    def get_color(self):
        return self.color
    
    def set_color(self, color):
        self.color = color


cookie_one = Cookie('green')
cookie_two = Cookie('blue')

print('COOKIE ONE IS', cookie_one.get_color())
print('COOKIE ONE IS', cookie_two.get_color())
# Out:
# COOKIE ONE IS green
# COOKIE ONE IS blue

# %%
class Cookie:
    def __init__ (self, color):
        self.color = color

    def get_color(self):
        return self.color
    
    def set_color(self, color):
        self.color = color


cookie_one = Cookie('green')
cookie_two = Cookie('blue')

print('COOKIE ONE IS', cookie_one.get_color())
print('COOKIE ONE IS', cookie_two.get_color())

cookie_one.set_color('yellow')

print('\nCookie one is now', cookie_one.get_color())
print('\nCookie two is still', cookie_two.get_color())
# Out:
# COOKIE ONE IS green
# COOKIE ONE IS blue
#
# Cookie one is now yellow
#
# Cookie two is still blue

# %%
nump1 = 11

nump2 = nump1

print("Before num2 value is update:")
print('nump1 = ', nump1)
print('nump2 = ', nump2)

print('\nnump1 points to: ', id(nump1))
print('\nnump2 points to: ', id(nump2))
# Out:
# Before num2 value is update:
# nump1 =  11
# nump2 =  11
#
# nump1 points to:  140675141960240
#
# nump2 points to:  140675141960240

# %%
nump1 = 11

nump2 = nump1

print("Before num2 value is update:")
print('nump1 = ', nump1)
print('nump2 = ', nump2)

print('\nnump1 points to: ', id(nump1))
print('\nnump2 points to: ', id(nump2))

nump2 = 22

print("After num2 value is update:")
print('nump1 = ', nump1)
print('nump2 = ', nump2)

print('\nnump1 points to: ', id(nump1))
print('\nnump2 points to: ', id(nump2))
# Out:
# Before num2 value is update:
# nump1 =  11
# nump2 =  11
#
# nump1 points to:  140675141960240
#
# nump2 points to:  140675141960240
# After num2 value is update:
# nump1 =  11
# nump2 =  22
#
# nump1 points to:  140675141960240
#
# nump2 points to:  140675141960592

# %%
dict1 = {
    'value' : 11
        }

dict2 = dict1

print("\n\nBefore value is update:")
print("dict1 = ", dict1)
print('dict2 = ', dict2)

print('\ndict1 points to: ', id(dict1))
print('\ndict2 points to: ', id(dict2))
# Out:
# Before value is update:
# dict1 =  {'value': 11}
# dict2 =  {'value': 11}
#
# dict1 points to:  140675078108480
#
# dict2 points to:  140675078108480

# %%
dict1 = {
    'value' : 11
        }



print("\n\nBefore value is update:")
print("dict1 = ", dict1)
print('dict2 = ', dict2)

print('\ndict1 points to: ', id(dict1))
print('\ndict2 points to: ', id(dict2))

dict2['value'] = 22

print("\n\nAfter value is update:")
print("dict1 = ", dict1)
print('dict2 = ', dict2)

print('\ndict1 points to: ', id(dict1))
print('\ndict2 points to: ', id(dict2))
# Out:
# Before value is update:
# dict1 =  {'value': 11}
# dict2 =  {'value': 22}
#
# dict1 points to:  140674947010496
#
# dict2 points to:  140674946973504
#
#
# After value is update:
# dict1 =  {'value': 11}
# dict2 =  {'value': 22}
#
# dict1 points to:  140674947010496
#
# dict2 points to:  140674946973504

# %%
class KalkulatorSederhana:
    def __init__(self, bilangan1, bilangan2):
        self.bilangan1 = bilangan1
        self.bilangan2 = bilangan2

    def setBilangan1(self, bilangan1):
        self.bilangan1 = bilangan1
    
    def setBilangan2(self, bilangan2):
        self.bilangan2 = bilangan2
    
    def tambah(self):
        return self.bilangan1 + self.bilangan2
        
    def pangkat(self):
        hasil = 1
        for i in range(self.bilangan2):
            hasil *= self.bilangan1
        return hasil
        

angka = KalkulatorSederhana(2, 3)
hasil_pertambahan = angka.tambah()
hasil_perpangkatan = angka.pangkat()

print('angka pertama adalah = ', angka.bilangan1)
print('angka kedua adalah = ', angka.bilangan2)
print('\nhasil pertambahan adalah = ', hasil_pertambahan)
print('\nhasil perpangkatan adalah = ', hasil_perpangkatan)
# Out:
# angka pertama adalah =  2
# angka kedua adalah =  3
#
# hasil pertambahan adalah =  5
#
# hasil perpangkatan adalah =  8
