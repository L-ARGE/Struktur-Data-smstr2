# %%
#Class Graph

class Graph:
    def __init__(self):
        self.adj_list = {}

    def print_graph(self):
        for vertex in self.adj_list:
            print(vertex, ":", self.adj_list[vertex])

my_graph = Graph()
my_graph.print_graph()

# %%
#Skenario 1 - Add Vertex

class Graph:
    def __init__(self):
        self.adj_list = {}

    def print_graph(self):
        for vertex in self.adj_list:
            print(vertex, ":", self.adj_list[vertex])

    def add_vertex(self, vertex):
        if vertex not in self.adj_list.keys():
            self.adj_list[vertex] = []
            return True
        return False
    
my_graph = Graph()
my_graph.add_vertex("A")
my_graph.print_graph()
# Out:
# A : []

# %%
#Skenario 2 - Add Edge
class Graph:
    def __init__(self):
        self.adj_list ={}

    def print_graph(self):
        for vertex in self.adj_list:
            print(vertex, ":", self.adj_list[vertex])

    def add_vertex(self, vertex):
        if vertex not in self.adj_list.keys():
            self.adj_list[vertex] = []
            return True
        return False

    def add_edge(self, v1, v2):
        if v1 in self.adj_list.keys() and v2 in self.adj_list.keys():
            self.adj_list[v1].append(v2)
            self.adj_list[v2].append(v1)
            return True
        return False

my_graph = Graph()
my_graph.add_vertex(1)
my_graph.add_vertex(2)

my_graph.add_edge(1,2)

my_graph.print_graph()
# Out:
# 1 : [2]
# 2 : [1]

# %%
#Skenario 3 - Remove Edge

class Graph:
    def __init__(self):
        self.adj_list = {}

    def print_graph(self):
        for vertex in self.adj_list:
            print(vertex, ':', self.adj_list[vertex])

    def add_vertex(self, vertex):
        if vertex not in self.adj_list.keys():
            self.adj_list[vertex] = []
            return True
        return False
    
    def add_edge(self, v1, v2):
        if v1 in self.adj_list.keys() and v2 in self.adj_list.keys():
            self.adj_list[v1].append(v2)
            self.adj_list[v2].append(v1)
            return True 
        return False
    
    def remove_edge(self, v1, v2):
        if v1 in self.adj_list.keys() and v2 in self.adj_list.keys():
            try:
                self.adj_list[v1].remove(v2)
                self.adj_list[v2].remove(v1)
            except ValueError:
                pass
            return True
        return False
    
my_graph = Graph()
my_graph.add_vertex('A')
my_graph.add_vertex('B')
my_graph.add_vertex('C')

my_graph.add_edge('A','B')
my_graph.add_edge('B','C')
my_graph.add_edge('C','A')

print('Graph before remove_edge():')
my_graph.print_graph()

my_graph.remove_edge('A', 'C')

print('\nGraph after remove_edge():')
my_graph.print_graph()
# Out:
# Graph before remove_edge():
# A : ['B', 'C']
# B : ['A', 'C']
# C : ['B', 'A']
#
# Graph after remove_edge():
# A : ['B']
# B : ['A', 'C']
# C : ['B']

# %%
#Skenario 4 - Remove Vertex

class Graph:
    def __init__(self):
        self.adj_list = {}

    def print_graph(self):
        for vertex in self.adj_list:
            print(vertex, ':', self.adj_list[vertex])

    def add_vertex(self, vertex):
        if vertex not in self.adj_list.keys():
            self.adj_list[vertex] = []
            return True
        return False
    
    def add_edge(self, v1, v2):
        if v1 in self.adj_list.keys() and v2 in self.adj_list.keys():
            self.adj_list[v1].append(v2)
            self.adj_list[v2].append(v1)
            return True 
        return False
    
    def remove_edge(self, v1, v2):
        if v1 in self.adj_list.keys() and v2 in self.adj_list.keys():
            try:
                self.adj_list[v1].remove(v2)
                self.adj_list[v2].remove(v1)
            except ValueError:
                pass
            return True
        return False

    def remove_vertex(self, vertex):
        if vertex in self.adj_list.keys():
            for other_vertex in self.adj_list[vertex]:
                self.adj_list[other_vertex].remove(vertex)
            del self.adj_list[vertex]
            return True
        return False
    
my_graph = Graph()
my_graph.add_vertex('A')
my_graph.add_vertex('B')
my_graph.add_vertex('C')
my_graph.add_vertex('D')

my_graph.add_edge('A','B')
my_graph.add_edge('A','C')
my_graph.add_edge('A','D')
my_graph.add_edge('B','D')
my_graph.add_edge('C','D')

print('Graph before remove_vertex():')
my_graph.print_graph()

my_graph.remove_vertex('D')

print('\nGraph after remove_vertex():')
my_graph.print_graph()
# Out:
# Graph before remove_vertex():
# A : ['B', 'C', 'D']
# B : ['A', 'D']
# C : ['A', 'D']
# D : ['A', 'B', 'C']
#
# Graph after remove_vertex():
# A : ['B', 'C']
# B : ['A']
# C : ['A']

# %%
#Latihan 1 - Implementasi Graph dengan Adjacency List

class Graph:
    def __init__(self):
        self.adj_list = {}

    def print_graph(self):
        for vertex in self.adj_list:
            print(vertex, ':', self.adj_list[vertex])

    def add_vertex(self, vertex):
        if vertex not in self.adj_list.keys():
            self.adj_list[vertex] = []
            return True
        return False
    
    def add_edge(self, v1, v2):
        if v1 in self.adj_list.keys() and v2 in self.adj_list.keys():
            self.adj_list[v1].append(v2)
            self.adj_list[v2].append(v1)
            return True 
        return False
    
my_graph = Graph()
my_graph.add_vertex('82')
my_graph.add_vertex('27')
my_graph.add_vertex('52')
my_graph.add_vertex('18')
my_graph.add_vertex('21')
my_graph.add_vertex('76')
my_graph.add_vertex('44')

my_graph.add_edge('82', '27')
my_graph.add_edge('27', '52')
my_graph.add_edge('52', '18')
my_graph.add_edge('18', '21')
my_graph.add_edge('18', '44')
my_graph.add_edge('21', '76')
my_graph.add_edge('44', '76')
my_graph.add_edge('44', '21')

my_graph.print_graph()
# Out:
# 82 : ['27']
# 27 : ['82', '52']
# 52 : ['27', '18']
# 18 : ['52', '21', '44']
# 21 : ['18', '76', '44']
# 76 : ['21', '44']
# 44 : ['18', '76', '21']

# %%
#Tugas

class Graph:
    def __init__(self):
        self.adj_list = {}

    def print_graph(self):
        for vertex in self.adj_list:
            print(vertex, ':', self.adj_list[vertex])

    def add_vertex(self, vertex):
        if vertex not in self.adj_list.keys():
            self.adj_list[vertex] = []
            return True
        return False
    
    def add_edge(self, v1, v2):
        if v1 in self.adj_list.keys() and v2 in self.adj_list.keys():
            self.adj_list[v1].append(v2)
            self.adj_list[v2].append(v1)
            return True 
        return False
    
    def remove_edge(self, v1, v2):
        if v1 in self.adj_list.keys() and v2 in self.adj_list.keys():
            try:
                self.adj_list[v1].remove(v2)
                self.adj_list[v2].remove(v1)
            except ValueError:
                pass
            return True
        return False

    def remove_vertex(self, vertex):
        if vertex in self.adj_list.keys():
            for other_vertex in self.adj_list[vertex]:
                self.adj_list[other_vertex].remove(vertex)
            del self.adj_list[vertex]
            return True
        return False
    
    def isInGraph(self, vertex):
        if vertex in self.adj_list.keys():
            return True
        return False


    def printAllConnected(self, vertex):
        if vertex in self.adj_list.keys():
            print(f"Vertex yang terhubung dengan {vertex}: {self.adj_list[vertex]}")
        else:
            print(f"Vertex {vertex} adalah vertex yang tidak ditemukan dalam graph.")

my_graph = Graph()
my_graph.add_vertex(82)
my_graph.add_vertex(27)
my_graph.add_vertex(52)
my_graph.add_vertex(18)
my_graph.add_vertex(21)
my_graph.add_vertex(76)
my_graph.add_vertex(44)

my_graph.add_edge(82, 27)
my_graph.add_edge(27, 52)
my_graph.add_edge(52, 18)
my_graph.add_edge(18, 21)
my_graph.add_edge(18, 44)
my_graph.add_edge(21, 76)
my_graph.add_edge(44, 76)
my_graph.add_edge(44, 21)

print('Graph before remove_vertex():')
my_graph.print_graph()

my_graph.remove_vertex(44)

print('\nGraph after remove_vertex():')
my_graph.print_graph()

print('\nTest fungsi IsInGraph():')
print(my_graph.isInGraph(82))
print(my_graph.isInGraph(27))
print(my_graph.isInGraph(52))
print(my_graph.isInGraph(18))
print(my_graph.isInGraph(21))
print(my_graph.isInGraph(76))
print(my_graph.isInGraph(44))

print('\nTest fungsi printAllConnected():')
my_graph.printAllConnected(82)
my_graph.printAllConnected(27)
my_graph.printAllConnected(52)
my_graph.printAllConnected(18)
my_graph.printAllConnected(21)
my_graph.printAllConnected(76)
my_graph.printAllConnected(44)
# Out:
# Graph before remove_vertex():
# 82 : [27]
# 27 : [82, 52]
# 52 : [27, 18]
# 18 : [52, 21, 44]
# 21 : [18, 76, 44]
# 76 : [21, 44]
# 44 : [18, 76, 21]
#
# Graph after remove_vertex():
# 82 : [27]
# 27 : [82, 52]
# 52 : [27, 18]
# 18 : [52, 21]
# 21 : [18, 76]
# 76 : [21]
#
# Test fungsi IsInGraph():
# True
# True
# True
# True
# True
# True
# False
#
# Test fungsi printAllConnected():
# Vertex yang terhubung dengan 82: [27]
# Vertex yang terhubung dengan 27: [82, 52]
# Vertex yang terhubung dengan 52: [27, 18]
# Vertex yang terhubung dengan 18: [52, 21]
# Vertex yang terhubung dengan 21: [18, 76]
# Vertex yang terhubung dengan 76: [21]
# Vertex 44 adalah vertex yang tidak ditemukan dalam graph.

# %%
#Latihan 1 - Implementasi Graph dengan Adjacency List

class Graph:
    def __init__(self):
        self.adj_list = {}

    def print_graph(self):
        for vertex in self.adj_list:
            print(vertex, ':', self.adj_list[vertex])

    def add_vertex(self, vertex):
        if vertex not in self.adj_list.keys():
            self.adj_list[vertex] = []
            return True
        return False
    
    def add_edge(self, v1, v2):
        if v1 in self.adj_list.keys() and v2 in self.adj_list.keys():
            self.adj_list[v1].append(v2)
            self.adj_list[v2].append(v1)
            return True 
        return False
    
    def get_degree(self, vertex):
        # Edge case: vertex tidak ada di dalam graph
        if vertex not in self.adj_list:
            print(f"Error: vertex '{vertex}' tidak ditemukan dalam graph.")
            return None
        
        # Degree = jumlah tetangga (panjang adjacency list vertex tersebut)
        return len(self.adj_list[vertex])
        
my_graph = Graph()
my_graph.add_vertex('82')
my_graph.add_vertex('27')
my_graph.add_vertex('52')
my_graph.add_vertex('18')
my_graph.add_vertex('21')
my_graph.add_vertex('76')
my_graph.add_vertex('44')

my_graph.add_edge('82', '27')
my_graph.add_edge('27', '52')
my_graph.add_edge('52', '18')
my_graph.add_edge('18', '21')
my_graph.add_edge('18', '44')
my_graph.add_edge('21', '76')
my_graph.add_edge('44', '76')
my_graph.add_edge('44', '21')


my_graph.print_graph()
print(my_graph.get_degree('18'))
print(my_graph.get_degree('44'))
print(my_graph.get_degree('99'))
print(my_graph.get_degree('82'))
# Out:
# 82 : ['27']
# 27 : ['82', '52']
# 52 : ['27', '18']
# 18 : ['52', '21', '44']
# 21 : ['18', '76', '44']
# 76 : ['21', '44']
# 44 : ['18', '76', '21']
# 3
# 3
# Error: vertex '99' tidak ditemukan dalam graph.
# None
# 1
