# %%
#LATIHAN SOAL NOMER 1

Nama_lengkap = input("Masukkan nama lengkap anda: ")
npm = int(input("Masukkan NPM milik anda: "))
Tanggal_lahir = (input("Masukkan tanggal(00)-bulan(00)-tahun(0000) kelahiran anda dengan format angka: "))

tanggal = int(Tanggal_lahir[0:2])
bulan = int(Tanggal_lahir[3:5])
tahun = int(Tanggal_lahir[6:10])

tanggal_hari_ini = 10
bulan_hari_ini = 2
tahun_hari_ini = 2026

usia = tahun_hari_ini - tahun
if (bulan, tanggal) > (bulan_hari_ini,tanggal_hari_ini):
    usia -= 1

print(f"Hai, {Nama_lengkap} NPM {npm}! Pada hari ini Selasa 10 Februari 2026 Anda berumur {usia} tahun. Selamat belajar Struktur Data!")
# Out:
# Hai, mikh NPM 78326847! Pada hari ini Selasa 10 Februari 2026 Anda berumur 18 tahun. Selamat belajar Struktur Data!

# %%
#LATIHAN SOAL NOMER 2 

bilangan_1 = int(input("Masukkan bilangan bulat pertama: "))
bilangan_2 = int(input("Masukkan bilangan bulat kedua: "))
print(f"Angka petama adalah :", bilangan_1)
print(f"Angka kedua adalah  :",bilangan_2)

print("Berikut hasil operasi matematika sederhana dari bilangan sebelumnya :")
print("")
print("=" * 36)

penjumlahan = bilangan_1 + bilangan_2
print(f"Hasil penjumlahan adalah        :", penjumlahan)
print("")

pengurangan = bilangan_1 - bilangan_2
print(f"Hasil pengurangan adalah        :", pengurangan)
print("")

perkalian = bilangan_1 * bilangan_2
print(f"Hasil perkalian adalah          :", perkalian)
print("")

if bilangan_2 != 0:
    pembagian = bilangan_1 // bilangan_2
    sisa_pembagian = bilangan_1 % bilangan_2

    print(f"Hasil pembagian adalah          :", pembagian)
    print("")

    if sisa_pembagian != 0:
        print(f"Sisa pembagian adalah           :",sisa_pembagian)
        print("")
else:
    pembagian = "TIdak bisa dibagi dengan nol (0)"


perpangkatan = 1
for i in range(bilangan_2):
    perpangkatan *= bilangan_1
print(f"Hasil perpangkatan adalah       :", perpangkatan)
print("=" * 36)
# Out:
# Angka petama adalah : 4
# Angka kedua adalah  : 2
# Berikut hasil operasi matematika sederhana dari bilangan sebelumnya :
#
# ...
# Hasil penjumlahan adalah        : 6
#
# Hasil pengurangan adalah        : 2
#
# Hasil perkalian adalah          : 8
#
# Hasil pembagian adalah          : 2
#
# Hasil perpangkatan adalah       : 16
# ...
