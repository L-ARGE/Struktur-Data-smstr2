# %%
pemain_tim_basket = {
    30: "Stephen Curry",
    23: "Draymond Green",
    1 : "LaMelo Ball",
    23: "LeBron James",
    3 : "Anthony Davis",
    5 : "Anthony Edwards",
    15: "Nikola Jokic",
    2 : "Shai Gilgeous-Alexander",
    7 : "Kevin Durant",
    34: "Giannis Antetokounmpo",
    18: "Russell Westbrook",
    11: "Kyrie Irving",
    77: "Luka Dončić",
    12: "Ja Morant",
    8 : "Yuki Kawamura"
}

print("Daftar pemain basket dengan nomor punggungnya: ")

for nomer, nama, in pemain_tim_basket.items():
    print(f"Nomor {nomer} : {nama}")
# Out:
# Daftar pemain basket dengan nomor punggungnya:
# Nomor 30 : Stephen Curry
# Nomor 23 : LeBron James
# Nomor 1 : LaMelo Ball
# Nomor 3 : Anthony Davis
# Nomor 5 : Anthony Edwards
# Nomor 15 : Nikola Jokic
# Nomor 2 : Shai Gilgeous-Alexander
# Nomor 7 : Kevin Durant
# Nomor 34 : Giannis Antetokounmpo
# Nomor 18 : Russell Westbrook
# Nomor 11 : Kyrie Irving
# Nomor 77 : Luka Dončić
# Nomor 12 : Ja Morant
# Nomor 8 : Yuki Kawamura
