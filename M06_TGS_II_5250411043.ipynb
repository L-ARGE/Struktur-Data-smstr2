# %%
class Node:
    def __init__(self, id, value):
        self.id = id
        self.value = value
        self.next = None
        self.prev = None

class DoublyLinkedList:
    def __init__(self):
            self.head = None
            self.tail = None
            self.length = 0

    def append_barang(self, id, value):
        new_node = Node(id, value)

        if self.head is None:
            self.head = new_node
            self.tail = new_node
        else:
            self.tail.next = new_node
            new_node.prev = self.tail
            self.tail = new_node
        self.length += 1

    def print_list(self):
        node_baru = self.head
        while node_baru is not None:
            print(f"id: {node_baru.id}, nama: {node_baru.value}")
            node_baru = node_baru.next
        print('')

#1. Identifikasi Objek dengan mencari Node B berdasarkan id
    def cari_byId(self, id):
        node_baru = self.head
        while node_baru is not None:
            if node_baru.id == id:
                return node_baru
            node_baru = node_baru.next
        return None
    
    def pop_first(self):
        if self.length == 0:
            return None
        
        temp = self.head
        if self.length == 1:
            self.head = None
            self.tail = None
        else:
            self.head = self.head.next
            self.head.prev = None
            temp.next = None
        self.length -= 1
        return temp
    
    def pop(self):
        if self.length == 0:
            return None
        
        temp = self.tail
        if self.length == 1:
            self.head = None
            self.tail = None
        else:
            self.tail = self.tail.prev
            self.tail.next = None
            temp.prev = None
        self.length -= 1
        return temp
    
    def hapus_node_byId(self, id):
        node_baru = self.cari_byId(id)

#2. class Node:
    def __init__(self, id, value):
        self.id = id
        self.value = value
        self.next = None
        self.prev = None

class DoublyLinkedList:
    def __init__(self):
            self.head = None
            self.tail = None
            self.length = 1

    def append_barang(self, id, value):
        new_node = Node(id, value)

        if self.head is None:
            self.head = new_node
            self.tail = new_node
        else:
            self.tail.next = new_node
            new_node.prev = self.tail
            self.tail = new_node
        self.length += 1

    def print_list(self):
        node_baru = self.head
        while node_baru is not None:
            print(f"id: {node_baru.id}, nama: {node_baru.value}")
            node_baru = node_baru.next
        print('')

#Langkah 1: Identifikasi Objek
    def cari_byId(self, id):
        node_baru = self.head
        while node_baru is not None:
            if node_baru.id == id:
                return node_baru
            node_baru = node_baru.next
        return None
    
    def pop_first(self):
        if self.length == 0:
            return None
        
        temp = self.head
        if self.length == 1:
            self.head = None
            self.tail = None
        else:
            self.head = self.head.next
            self.head.prev = None
            temp.next = None
        self.length -= 1
        return temp
    
    def pop(self):
        if self.length == 0:
            return None
        
        temp = self.tail
        if self.length == 1:
            self.head = None
            self.tail = None
        else:
            self.tail = self.tail.prev
            self.tail.next = None
            temp.prev = None
        self.length -= 1
        return temp
    
    def hapus_node_byId(self, id):
        node_baru = self.cari_byId(id)

#Langkah 2: Penelusuran Logika Pointer
        if node_baru is None:
            return None
        if node_baru == self.head:
            return self.pop_first()
        if node_baru == self.tail:
            return self.pop()


        node_baru.prev.next = node_baru.next
        node_baru.next.prev = node_baru.prev
        node_baru.next = None
        node_baru.prev = None

        self.length -= 1
        return node_baru
    
#Langkah 4: Manajemen Atribut & Integritas Data
    def ukuran_dll(self):
        return self.length
    

dll = DoublyLinkedList()
print('Urutan Barang dengan Id: ')
dll.append_barang("001", "Mouse")
dll.append_barang("002", "Keyboard")
dll.append_barang("003", "Monitor")

dll.print_list()

print('Menghapus Barang dengan Id: 002')
dll.hapus_node_byId("002")

dll.print_list()

print('Ukuran DLL saat ini: ')
dll.ukuran_dll()
# Out:
# Urutan Barang dengan Id:
# id: 001, nama: Mouse
# id: 002, nama: Keyboard
# id: 003, nama: Monitor
#
# Menghapus Barang dengan Id: 002
# id: 001, nama: Mouse
# id: 003, nama: Monitor
#
# Ukuran DLL saat ini:
# 3

# %% [markdown]
# Langkah 2: Penelusuran Logika Pointer
# 1. Baris kode yang mengubah next milik Node A adalah 'node_baru.prev.next = node_baru.next'. Kita menggunakan atribut .prev.next karena kita ingin melakukan perubahan pada pointer next milik node sebelumnya (Node A). Dengan atribut .prev kita bisa mengakses node sebelumnya (Node A) dan dengan atribut .next milik node A juga kita bisa mengubah pointer agar bisa langsung mengarah ke node selanjutnya (Node C). Sehingga node yang terlewatkan (Node B) akan terhapus.
#
# 2. Baris kode yang mengubah prev milik Node C adalah 'node_baru.next.prev = node_baru.prev'. Dengan adanya kode ini, maka prev milik Node C yang semula mengarah ke Node B berubah menjadi Node A.
#
# Langkah 3: Analisis Konektivitas
# 1. Tidak bisa. Ini bisa terjadi karena pointer next milik Node A sudah diubah arahnya menuju ke Node C. Sehingga, Node B sudah tidak lagi tergabung didalam Doubly Linked List. Faktor lainnya juga bisa terjadi karena telah dilakukannya operasi penghapusan Node B, sehingga pointer next milik Node A diubah ke Node C melalui baris kode 'node_baru.prev.next = node_baru.next'
#
# 2. Tidak bisa. Dikarenakan telah terjadi penghapusan Node B, pointer prev milik Node C telah diubah untuk bisa langsung menunjuk ke Node A dengan perintah 'node_baru.next.prev = node_baru.prev'. Sehingga Node B sudah tidak lagi terhubung dengan Doubly Linked List.
#
# Langkah 4: Manajemen Atribut dan Integritas Data
# 1. Baris kode yang bisa memperbarui atribut jumlah total barang dalam list adalah
# 'def ukuran_dll(self):
#         return self.length'
# yang di panggil fungsinya melalui kode :'dll.ukuran_dll()'
#
# 2.
